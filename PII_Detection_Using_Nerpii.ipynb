# %%
# !pip install nerpii
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nerpii
#   Downloading nerpii-0.1.4-py3-none-any.whl (8.8 kB)
# Collecting faker<18.0.0,>=17.3.0 (from nerpii)
#   Downloading Faker-17.6.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.3 MB/s eta 0:00:00
# Collecting gender-guesser<0.5.0,>=0.4.0 (from nerpii)
#   Downloading gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.3/379.3 kB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0.0,>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from nerpii) (1.5.3)
# Collecting presidio-analyzer<3.0.0,>=2.2.32 (from nerpii)
#   Downloading presidio_analyzer-2.2.32-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 6.9 MB/s eta 0:00:00
# Collecting simple-colors<0.2.0,>=0.1.5 (from nerpii)
#   Downloading simple_colors-0.1.5-py3-none-any.whl (2.8 kB)
# Requirement already satisfied: spacy<4.0.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from nerpii) (3.5.2)
# Collecting torch<2.0.0,>=1.13.1 (from nerpii)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 2.0 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.26.1 (from nerpii)
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 32.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker<18.0.0,>=17.3.0->nerpii) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.5.3->nerpii) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.5.3->nerpii) (1.22.4)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.32->nerpii) (2022.10.31)
# Collecting tldextract (from presidio-analyzer<3.0.0,>=2.2.32->nerpii)
#   Downloading tldextract-3.4.4-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from presidio-analyzer<3.0.0,>=2.2.32->nerpii) (6.0)
# Collecting phonenumbers>=8.12 (from presidio-analyzer<3.0.0,>=2.2.32->nerpii)
#   Downloading phonenumbers-8.13.11-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.5.0->nerpii) (3.3.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<2.0.0,>=1.13.1->nerpii) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2.0.0,>=1.13.1->nerpii)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 30.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2.0.0,>=1.13.1->nerpii)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2.0.0,>=1.13.1->nerpii)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2.0.0,>=1.13.1->nerpii)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 38.3 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.13.1->nerpii) (0.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.26.1->nerpii) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers<5.0.0,>=4.26.1->nerpii)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.8 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.26.1->nerpii)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 43.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers<5.0.0,>=4.26.1->nerpii) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker<18.0.0,>=17.3.0->nerpii) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->nerpii) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->nerpii) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->nerpii) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.5.0->nerpii) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4.0.0,>=3.5.0->nerpii) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4.0.0,>=3.5.0->nerpii) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4.0.0,>=3.5.0->nerpii) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.5.0->nerpii) (2.1.2)
# Collecting requests-file>=1.4 (from tldextract->presidio-analyzer<3.0.0,>=2.2.32->nerpii)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Installing collected packages: tokenizers, simple-colors, phonenumbers, gender-guesser, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, requests-file, nvidia-cudnn-cu11, huggingface-hub, faker, transformers, torch, tldextract, presidio-analyzer, nerpii
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed faker-17.6.0 gender-guesser-0.4.0 huggingface-hub-0.14.1 nerpii-0.1.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 phonenumbers-8.13.11 presidio-analyzer-2.2.32 requests-file-1.5.1 simple-colors-0.1.5 tldextract-3.4.4 tokenizers-0.13.3 torch-1.13.1 transformers-4.29.2

# %%
import pandas as pd

from nerpii.named_entity_recognizer import NamedEntityRecognizer, split_name
from nerpii.faker_generator import FakerGenerator

# %%
personal_info = pd.read_csv('PII_Detection_Input.csv')
personal_info.head(10)
# Out:
#    First_Name Last_Name                               Country  Phone_Number
# 0  Maximilian   Spencer                               Austria  128-075-9247
# 1       Bruno    Mareli                               Myanmar  188-319-3089
# 2        Lina    Gloria                Bosnia and Herzegovina  230-254-7517
# 3      Teresa    Lamont                             Swaziland  299-291-7118
# 4    Terrence     Tania                                 Palau  245-091-9288
# 5      Paityn   Justine                Svalbard and Jan Mayen  518-088-5586
# 6      Austin      Tony                                Greece  058-484-6421
# 7      Lennon   Roberto                          Sierra Leone  444-737-6565
# 8      Jadiel  Jennifer  United States Minor Outlying Islands  558-722-6582
# 9       Lilah     Kason                         Aland Islands  462-021-4097

# %%
recognizer = NamedEntityRecognizer(personal_info)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
recognizer.assign_entities_with_presidio()
recognizer.assign_entities_manually()
recognizer.assign_organization_entity_with_model()
# Out:
# WARNING:presidio-analyzer:configuration file /usr/local/lib/python3.10/dist-packages/conf/default.yaml not found.  Using default config: {'nlp_engine_name': 'spacy', 'models': [{'lang_code': 'en', 'model_name': 'en_core_web_lg'}]}.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/433M [00:00<?, ?B/s]

# %%
recognizer.dict_global_entities
# Out:
# {'First_Name': {'entity': 'PERSON', 'confidence_score': 0.8986486486486487},
#  'Last_Name': {'entity': 'PERSON', 'confidence_score': 0.9280575539568345},
#  'Country': {'entity': 'LOCATION', 'confidence_score': 0.9368421052631579},
#  'Phone_Number': {'entity': 'PHONE_NUMBER',
#   'confidence_score': 0.9318181818181818},
#  'first_name_gender': None}

# %%
faker_generator = FakerGenerator(personal_info, recognizer.dict_global_entities)

# %%
faker_generator.get_faker_generation()
# Out:
# Column Phone_Number synthesized with Faker.
# Column First_Name synthesized with Faker.
# Column Last_Name synthesized with Faker.
# Column Country synthesized with Faker.

# %%
personal_info
# Out:
#     First_Name Last_Name                    Country            Phone_Number
# 0        Kayla    Knight                    Uruguay  001-563-076-4797x46945
# 1      Crystal   Elliott                     Jordan              8824319741
# 2        Emily    Carson          Equatorial Guinea            024.986.8454
# 3        Kayla     Boone               Sierra Leone  001-783-778-7192x11525
# 4       Angela   Baldwin                   Bulgaria      496-683-4141x10542
# ..         ...       ...                        ...                     ...
# 195   Patricia   Parsons                    Morocco      (350)044-0028x1703
# 196     Joanne    Hudson                     Jordan      (852)942-5064x7341
# 197    Natasha     Cline                   Pakistan         +1-563-598-1941
# 198     Ashley     Green              French Guiana  001-941-066-0243x54686
# 199    Brianna    Carter  Bouvet Island (Bouvetoya)   001-276-110-8215x8929
#
# [200 rows x 4 columns]
